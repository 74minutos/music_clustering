# %% [markdown]
# # Music Data Analysis
#
# En este notebook vamos a extraer información de metadata sobre un dataset de 7.000 canciones a través de la API de spotify. La explicación y el walkthrough del mismo la podéis encontrar [aquí](https://visiondefunnel.com/2021/05/21/suenan-los-androides-con-generos-musicales). En general, lo que queremos es entender cómo reaccionan los clusters del algoritmo K-Means con un conjunto de datos que describen númericamente esas canciones.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
path_to_data = "songs_with_audio_features.csv"
data = pd.read_csv(path_to_data, index_col=False, delimiter=";")
data.head()
# Out:
#                          track_name                      id  \
# 0            Dreams - 2004 Remaster  0ofHAoxe9vBkTCp2UQIavz
# 1         The Chain - 2004 Remaster  5e9TFTbltYBg2xThimr0rU
# 2                Sweet Home Alabama  7e89621JPkKaeDSTQ3avtg
# 3  Hotel California - 2013 Remaster  40riOy7x9W7GXjyGp4pjAv
# 4                      Mr. Blue Sky  2RlgNHKcydI9sayD2Df2xp
#
#                          album_name               artist_name  popularity  \
# 0            Rumours (Super Deluxe)             Fleetwood Mac          85
# 1            Rumours (Super Deluxe)             Fleetwood Mac          82
# 2                    Second Helping            Lynyrd Skynyrd          82
# 3  Hotel California (2013 Remaster)                    Eagles          83
# 4                   Out of the Blue  Electric Light Orchestra          81
#
#    decade                                              genre  danceability  \
# 0    1970  ['album rock', 'classic rock', 'mellow gold', ...         0.828
# 1    1970  ['album rock', 'classic rock', 'mellow gold', ...         0.545
# 2    1970  ['album rock', 'blues rock', 'classic rock', '...         0.596
# 3    1970  ['album rock', 'classic rock', 'country rock',...         0.579
# 4    1970  ['album rock', 'art rock', 'beatlesque', 'bow ...         0.388
#
#    energy  key  ...  instrumentalness  liveness  valence    tempo  \
# 0   0.492    0  ...          0.004280    0.1280    0.789  120.151
# 1   0.670    9  ...          0.000822    0.0451    0.481  151.553
# 2   0.605    7  ...          0.000331    0.0863    0.886   97.798
# 3   0.508    2  ...          0.000494    0.0575    0.609  147.125
# 4   0.338   10  ...          0.000004    0.2480    0.478  177.765
#
#              type                                   uri  \
# 0  audio_features  spotify:track:0ofHAoxe9vBkTCp2UQIavz
# 1  audio_features  spotify:track:5e9TFTbltYBg2xThimr0rU
# 2  audio_features  spotify:track:7e89621JPkKaeDSTQ3avtg
# 3  audio_features  spotify:track:40riOy7x9W7GXjyGp4pjAv
# 4  audio_features  spotify:track:2RlgNHKcydI9sayD2Df2xp
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0ofHAoxe9vBk...
# 1  https://api.spotify.com/v1/tracks/5e9TFTbltYBg...
# 2  https://api.spotify.com/v1/tracks/7e89621JPkKa...
# 3  https://api.spotify.com/v1/tracks/40riOy7x9W7G...
# 4  https://api.spotify.com/v1/tracks/2RlgNHKcydI9...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0ofH...      257800
# 1  https://api.spotify.com/v1/audio-analysis/5e9T...      270213
# 2  https://api.spotify.com/v1/audio-analysis/7e89...      283800
# 3  https://api.spotify.com/v1/audio-analysis/40ri...      391376
# 4  https://api.spotify.com/v1/audio-analysis/2Rlg...      303373
#
#   time_signature
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4
#
# [5 rows x 24 columns]

# %%
data['genre'] = data['genre'].str.replace("'", "")
data['genre'] = data['genre'].str.strip('()').str.split(',')
data = data.explode('genre', ignore_index=True)

# %%
genre = data.pop('genre')
artist_name = data.pop('artist_name')
album_name = data.pop('album_name')
ids = data.pop('id')
track_name = data.pop('track_name')
decade = data.pop('decade')
data.drop(columns=['uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature', 'type'], inplace=True)
data.head()
# Out:
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          85         0.828   0.492    0    -9.744     1       0.0276
# 1          85         0.828   0.492    0    -9.744     1       0.0276
# 2          85         0.828   0.492    0    -9.744     1       0.0276
# 3          85         0.828   0.492    0    -9.744     1       0.0276
# 4          85         0.828   0.492    0    -9.744     1       0.0276
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0        0.0644           0.00428     0.128    0.789  120.151
# 1        0.0644           0.00428     0.128    0.789  120.151
# 2        0.0644           0.00428     0.128    0.789  120.151
# 3        0.0644           0.00428     0.128    0.789  120.151
# 4        0.0644           0.00428     0.128    0.789  120.151

# %% [markdown]
# ### Normalization
#
# El siguiente paso recoge las operaciones a realizar para normalizar los datos. Con normalizar lo que queremos decir es que ponemos todas las variables en la misma escala de valores para que el modelo de clustering pueda tratarlos de la misma manera.

# %%
x = data.values
x = np.nan_to_num(x)

sc = StandardScaler()
cluster_data = sc.fit_transform(x)

# %% [markdown]
# #### Modelo
#
# Entrenamos el modelo con los datos que hemos obtenido en el paso anterior. Esto iterará hasta conseguir la mejor posición de los centroids.

# %%
clusters = 8
model = KMeans(init = 'k-means++', n_clusters = clusters, n_init = 12)
model.fit(cluster_data)

labels = model.labels_
data['cluster_num'] = labels

# %%
data.groupby('cluster_num').mean()
# Out:
#              popularity  danceability    energy       key   loudness  \
# cluster_num
# 0              0.822072      0.727178  0.727613  5.054054  -4.766239
# 1             67.576175      0.462149  0.780895  5.090055  -6.069742
# 2             67.305781      0.590506  0.737003  5.346393  -7.100661
# 3             65.469973      0.540773  0.365902  5.167954 -12.307243
# 4             68.989865      0.685413  0.673910  6.018711  -7.650720
# 5             71.471109      0.759410  0.645556  6.053618  -7.068259
# 6             66.210759      0.691103  0.658573  4.840905  -8.393477
# 7             64.933417      0.510317  0.627146  5.579146 -10.452702
#
#                  mode  speechiness  acousticness  instrumentalness  liveness  \
# cluster_num
# 0            0.522523     0.112710      0.199801          0.000587  0.152138
# 1            0.842404     0.063843      0.077569          0.017020  0.157678
# 2            0.765409     0.071409      0.155668          0.015414  0.504591
# 3            0.848742     0.041769      0.557863          0.017055  0.140352
# 4            0.000000     0.061988      0.162088          0.009085  0.140278
# 5            0.502343     0.309635      0.150298          0.005159  0.176713
# 6            1.000000     0.051622      0.181511          0.008353  0.130884
# 7            0.672111     0.055354      0.228169          0.690741  0.157679
#
#               valence       tempo
# cluster_num
# 0            0.661014  125.563226
# 1            0.452843  139.319795
# 2            0.605761  119.133641
# 3            0.410311  116.799005
# 4            0.655709  116.612361
# 5            0.580122  118.943317
# 6            0.737350  114.214984
# 7            0.488602  120.572481

# %%
# axes instance
fig = plt.figure(figsize=(10,10))
ax = Axes3D(fig, 
            rect = [0, 0, .95, 1], 
            elev = 10, 
            azim = 75,
            auto_add_to_figure=False)
fig.add_axes(ax)
cmap = 'winter'

# plot
sc = ax.scatter(data['danceability'], data['energy'], 
                data['loudness'], s=75, c=data['cluster_num'], marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('danceability')
ax.set_ylabel('energy')
ax.set_zlabel('loudness')

# legend
plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)

# %%
# axes instance
fig = plt.figure(figsize=(10,10))
ax = Axes3D(fig, 
            rect = [0, 0, .95, 1], 
            elev = 12, 
            azim = 75,
            auto_add_to_figure=False)
fig.add_axes(ax)

# plot
sc = ax.scatter(data['instrumentalness'], data['acousticness'], 
                data['loudness'], s=75, c=data['cluster_num'], marker='o', cmap='autumn', alpha=1)
ax.set_xlabel('instrumentalness')
ax.set_ylabel('acosuticness')
ax.set_zlabel('loudness')

# legend
plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)

# %%
#creamos un dataset nuevo en el que introducimos de nuevo los parámetros que nos interesaban en la clusterización
data_to_check = data.join([decade, genre, track_name, album_name, artist_name])
data_to_check.head()
# Out:
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          85         0.828   0.492    0    -9.744     1       0.0276
# 1          85         0.828   0.492    0    -9.744     1       0.0276
# 2          85         0.828   0.492    0    -9.744     1       0.0276
# 3          85         0.828   0.492    0    -9.744     1       0.0276
# 4          85         0.828   0.492    0    -9.744     1       0.0276
#
#    acousticness  instrumentalness  liveness  valence    tempo  cluster_num  \
# 0        0.0644           0.00428     0.128    0.789  120.151            6
# 1        0.0644           0.00428     0.128    0.789  120.151            6
# 2        0.0644           0.00428     0.128    0.789  120.151            6
# 3        0.0644           0.00428     0.128    0.789  120.151            6
# 4        0.0644           0.00428     0.128    0.789  120.151            6
#
#    decade          genre              track_name              album_name  \
# 0    1970    [album rock  Dreams - 2004 Remaster  Rumours (Super Deluxe)
# 1    1970   classic rock  Dreams - 2004 Remaster  Rumours (Super Deluxe)
# 2    1970    mellow gold  Dreams - 2004 Remaster  Rumours (Super Deluxe)
# 3    1970           rock  Dreams - 2004 Remaster  Rumours (Super Deluxe)
# 4    1970      soft rock  Dreams - 2004 Remaster  Rumours (Super Deluxe)
#
#      artist_name
# 0  Fleetwood Mac
# 1  Fleetwood Mac
# 2  Fleetwood Mac
# 3  Fleetwood Mac
# 4  Fleetwood Mac

# %%
num_clusters = np.unique(data_to_check['cluster_num'])
fig, ax = plt.subplots(int(len(num_clusters)/4),4,figsize=(16,10))

ax = ax.ravel()
ax[-2].set_axis_off()

for i, (cluster, axes) in enumerate(zip(num_clusters, ax)):
    generate_data = data_to_check[data_to_check['cluster_num'].isin([cluster])]
    wc = WordCloud(width=750, height=500, random_state=i, stopwords=['list', "album"])
    wc.generate(str(generate_data['genre'].values).replace("'", "").replace("[", "").replace("]", ""))
    img = wc.to_array()[:,:,0]
    axes.imshow(img) 
    axes.set_axis_off()
    axes.set_title('Cluster {}'.format(cluster))
    
fig.subplots_adjust(wspace=0.05, hspace=0.05)
